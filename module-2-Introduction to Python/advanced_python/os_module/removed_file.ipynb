# %%
file=open("removed_file.txt","w")
print("read file")
file.close()
# Out:
# read file

# %%
import os 
if os.path.exists("removed_file.txt"):
    os.remove("removed_file.txt")
    print("removed")
else:
    print("file does not exists")
# Out:
# removed
