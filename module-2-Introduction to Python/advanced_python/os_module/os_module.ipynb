# %%
# os module is an module used in python basically for delete a file 
# os module is an module used in python basically for empty directory in a python
# os module is an inbuilt module in python 
import os 
file=open("regression_model.txt","w")
print("created successfully")
file.close()
# Out:
# created successfully

# %%
import os
if os.path.exists
    os.remove()
