# %%
file=open("structured_data.txt","w")
print("file opened and created")
# Out:
# file opened and created

# %%
# file=open("structured_data.txt","w")
# # print("file opened and created")
# text='structured data is form of excel or tables or csv'
# res=file.write(text)
# print(res)
# Out:
# 49

# %%
file=open("structured_data.txt","r")
# print("file opened and created")
# text='structured data is form of excel or tables or csv'
# res=file.write(text)
res=file.read()
print(res)
# Out:
# structured data is form of excel or tables or csv

# %%
file=open("structured_data.txt","r")
# print("file opened and created")
# text='structured data is form of excel or tables or csv'
# res=file.write(text)
res=file.read(32)
print(res)
# Out:
# structured data is form of excel

# %%
try:
    file=open("structured_data.txt","r")
    res=file.read(32)
    print(res)

finally:
     file.close() # closed the file
# Out:
# structured data is form of excel

# %%
try:
    file=open("datascience.txt","w") 
    txt=input('Enter a name')
    res=file.write(txt)
except:
    print("file generate error")
else:
    print("file not read any content")
finally:
    file.close()
# Out:
# Enter a name brijesh kumar pandey
# file not read any content

# %%
# try:
#     file=open("datascience.txt","r") 
#     #txt=input('Enter a name')
#     res=file.read(txt)
# except:
#     print("file generate error")
# else:
#     print("file successfully read  content")
# finally:
#     file.close()
# Out:
# file generate error

# %%
try:
    file=open("datascience.txt","r") 
    #txt=input('Enter a name')
    res=file.read()
except:
    print("file generate error")
else:
    print("file successfully read  content",res)
finally:
    file.close()
# Out:
# file successfully read  content brijesh kumar pandey

# %%
try:
    a=int(input("Enter a values"))
    b=int(input("Enter b values"))
    c=a+b;
    print(x)
except: 
    print("generate something error")
else:
    print("The additions of numbers is :",c)
finally:
    # f.close();
    print("executed")
# Out:
# Enter a values 10
# Enter b values 20
# print only string values
# executed
