# %%
# open a file 
# r is a mode that can be read a file if file is not found error
# file=open("hello.txt","r")
# if file:
#     print("file oppend successfully")
# else:
#     print("somthing went wrong")
# file not found generate error
# r+ is a mode that can be read and write a file if file is not found error

# file=open("hello.txt","r+")
# txt="hi brijesh"
# if file:
#     print("file oppend successfully",txt)
# else:
#     print("somthing went wrong")

# w is a mode that can be write a file if file is not found create a new file
# file=open("datascience.txt","w")
# if file:
#     print("file oppend successfully")
# else:
#     print("somthing went wrong")



# w+ is a mode that can be read and write on file if file is not found create a new file and overwrite on file
# file=open("dataanalytics.txt","w")
# if file:
#     print("file oppend successfully")
# else:
#     print("somthing went wrong")



# a append only on the end of file (add data to end) if file is not available create a new file also 

# file=open("data.txt","a")
# if file:
#     print("file oppend successfully")
# else:
#     print("somthing went wrong")

# for write on file 
# txt="hi devanshu"
# print(file.write(txt))

# a+ read and  append  on the end of file (add data to end) if file is not available create a new file also     

# file=open("data.txt","a+")
# if file:
#     txt="hi brijesh"
#     print(file.write(txt))
#     print("file oppend successfully")
# else:
#     print("somthing went wrong and not able to write")


# rb : Read in binary mode 


# file=open("hello.txt","r+")

# if file:
#     txt="hi brijesh"
#     print(file.write(txt));
#     print("file oppend successfully",txt)
# else:
#     print("somthing went wrong")


# file=open("test.txt","w")

# if file:
#     txt="hi brijesh"
#     print(file.write(txt));
#     print("file oppend successfully",txt)
# else:
#     print("somthing went wrong")



file=open("ajax.txt","w")

if file:
    txt="hi brijesh"
    print(file.write(txt));
    print("file oppend successfully",txt)
else:
    print("somthing went wrong")
# Out:
# 10
# file oppend successfully hi brijesh
