# %%
# what is file handeling in python ? 
# file handeling is used to handel file in python 
# file handeling is used to read file | wirte on file | create file | open file | delete a file 
# in python using its function 
# file handeling methods ....

# How to handel file using method ......

# How to open file 
 # open('filename',mode)
 # name of file 
 # mode of file (read | write | append)
