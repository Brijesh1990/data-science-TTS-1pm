# %%
# excel  is also know as spreadsheet 
# A pandas used to read a excel file content in python 
# create a python file to read content of excel
# create a csv file (employee.csv o data.)
# json file is used for web services or api content in .json 
# read a file content of json we used read_json() method in python
import pandas as pd 
res=pd.read_excel('employee.xlsx', engine="openpyxl")
print(res)
# Out:
#    Employee ID          Name Department                    Email       Phone  \
# 0       EMP001    Employee 1         IT    employee1@company.com  9876500001
# 1       EMP002    Employee 2    Finance    employee2@company.com  9876500002
# 2       EMP003    Employee 3  Marketing    employee3@company.com  9876500003
# 3       EMP004    Employee 4      Sales    employee4@company.com  9876500004
# 4       EMP005    Employee 5         HR    employee5@company.com  9876500005
# ..         ...           ...        ...                      ...         ...
# 95      EMP096   Employee 96         IT   employee96@company.com  9876500096
# 96      EMP097   Employee 97    Finance   employee97@company.com  9876500097
# 97      EMP098   Employee 98  Marketing   employee98@company.com  9876500098
# 98      EMP099   Employee 99      Sales   employee99@company.com  9876500099
# 99      EMP100  Employee 100         HR  employee100@company.com  9876500100
#
#          City  Salary
# ...
