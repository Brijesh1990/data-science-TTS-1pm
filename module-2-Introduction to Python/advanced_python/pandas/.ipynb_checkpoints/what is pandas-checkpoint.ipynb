# %%
# pandas is a library of python 
# pandas should be install via pip install pandas 
# pandas comes from pandas library 
# import pandas as pd 
# pandas is used to analyze data
# pandas is used to working with data set ex: excel | csv  etc
# pandas has functions for anlyzing , cleaning , exploring and manupulating data
# pandas name "pandas" has a refrences to both 'panel Data' and "python Data anlysis" created by wes mckinney in 2008

# why used pandas 

# pandas allows us to anlyze big data 
# pandas allows to make conclusion based on statistical theories 
# pandas can clean messy data sets and make them redable and relevant 
# pandas is make relevant data it is very important in data science 

# what can pandas do ?
# pandas find average values from data sets
# pandas find max or min values from data sets 
# pandas also used to delete rows that are not releveant 

ipmort pandas from pd
