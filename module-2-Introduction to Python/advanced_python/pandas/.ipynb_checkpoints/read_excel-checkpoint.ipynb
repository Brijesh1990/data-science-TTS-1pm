# %%
# excel  is also know as spreadsheet 
# A pandas used to read a excel file content in python 
# create a python file to read content of excel
# create a csv file (employee.csv o data.)
# json file is used for web services or api content in .json 
# read a file content of json we used read_json() method in python
import pandas as pd 
res=pd.read_excel('empploee.xlsx', engine="openpyxl")
print(res)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[6], line 8
#       1 # excel  is also know as spreadsheet
#       2 # A pandas used to read a excel file content in python
#       3 # create a python file to read content of excel
#       4 # create a csv file (employee.csv o data.)
#       5 # json file is used for web services or api content in .json
#       6 # read a file content of json we used read_json() method in python
#       7 import pandas as pd
# ----> 8 res=pd.read_excel('employee_data.agent.xlsx', engine="openpyxl")
#       9 print(res)
#
# ...

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...
