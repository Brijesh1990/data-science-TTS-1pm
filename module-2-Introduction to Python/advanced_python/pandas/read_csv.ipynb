# %%
# CSV stands for comma seperated values 
# A pandas used to read a CSV file content in python 
# A CSV contains plain text and is well know that can be read by everyone including pandas 
# create a python file to read content of CSV 
# create a csv file (employee.csv o data.csv)
# read_csv() is a method that is used to read a CSV file formate in python

import pandas as pd
res=pd.read_csv('data.csv')
print(res)
# Out:
#    ID     Name Department  Experience_Years
# 0   1  Brijesh         IT                12
# 1   2     Amit         HR                 5
# 2   3     Neha    Finance                 3
# 3   4     Ravi         IT                 8
# 4   5    Priya  Marketing                 4

# %%
# using to_string() method 
# return all data in entire data in string fromate 

import pandas as pd
res=pd.read_csv('data.csv')
print(res.to_string())
# Out:
#    ID     Name Department  Experience_Years
# 0   1  Brijesh         IT                12
# 1   2     Amit         HR                 5
# 2   3     Neha    Finance                 3
# 3   4     Ravi         IT                 8
# 4   5    Priya  Marketing                 4

# %%
import pandas as pd
res=pd.read_csv('employee.csv')
print(res.to_string())
# Out:
#    Employee_ID    Name  Department       Designation  Experience_Years  Salary_INR
# 0       EMP001  Kavita     Finance  Senior Executive                12       29908
# 1       EMP002    Amit  Operations           Manager                10       80172
# 2       EMP003   Anita  Operations         Executive                11       61811
# 3       EMP004   Pooja          IT           Analyst                 4       43812
# 4       EMP005   Priya       Sales         Team Lead                 4       98372
# 5       EMP006   Karan       Sales           Manager                 2      119998
# 6       EMP007  Deepak  Operations           Analyst                 8      111771
# 7       EMP008  Suresh   Marketing           Manager                 6       47014
# 8       EMP009   Rahul     Finance           Analyst                 4       59071
# 9       EMP010   Arjun          HR         Executive                12       42188
# ...

# %%
import pandas as pd
res=pd.read_csv('employee.csv')
print(res)
# Out:
#    Employee_ID    Name  Department       Designation  Experience_Years  \
# 0       EMP001  Kavita     Finance  Senior Executive                12
# 1       EMP002    Amit  Operations           Manager                10
# 2       EMP003   Anita  Operations         Executive                11
# 3       EMP004   Pooja          IT           Analyst                 4
# 4       EMP005   Priya       Sales         Team Lead                 4
# ..         ...     ...         ...               ...               ...
# 95      EMP096    Ravi          IT         Executive                 5
# 96      EMP097    Ravi     Support           Manager                14
# 97      EMP098    Isha     Support         Executive                 9
# 98      EMP099   Sneha       Sales         Executive                 3
# 99      EMP100   Vikas   Marketing         Executive                14
#
#     Salary_INR
# 0        29908
# 1        80172
# 2        61811
# 3        43812
# 4        98372
# ..         ...
# ...

# %%
# to increase a max data from csv 
import pandas as pd
pd.options.display.max_rows=9999
res=pd.read_csv('employee.csv')
print(res)
# Out:
#    Employee_ID    Name  Department       Designation  Experience_Years  \
# 0       EMP001  Kavita     Finance  Senior Executive                12
# 1       EMP002    Amit  Operations           Manager                10
# 2       EMP003   Anita  Operations         Executive                11
# 3       EMP004   Pooja          IT           Analyst                 4
# 4       EMP005   Priya       Sales         Team Lead                 4
# 5       EMP006   Karan       Sales           Manager                 2
# 6       EMP007  Deepak  Operations           Analyst                 8
# 7       EMP008  Suresh   Marketing           Manager                 6
# 8       EMP009   Rahul     Finance           Analyst                 4
# 9       EMP010   Arjun          HR         Executive                12
# 10      EMP011   Arjun   Marketing           Manager                 8
# 11      EMP012  Deepak     Support           Manager                14
# ...
