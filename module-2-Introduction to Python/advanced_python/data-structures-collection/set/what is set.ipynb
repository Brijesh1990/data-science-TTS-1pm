# %%
# set : python set is mutable can be add | update  
# set is collection of mutable data object stored in unordered 
# set is defined inside of {} not need to paired inform of key:value becuase stored in unordered 
# set is used its constructor set()

set1={1,2,3,4,5,6}
print(set1)
print(type(set1))
# Out:
# {1, 2, 3, 4, 5, 6}
# <class 'set'>

# %%
set1=set()
print(type(set1))
# Out:
# <class 'set'>

# %%
# set can be stored any data type 
set1=set("hi i am brijesh")
print(type(set1))
# Out:
# <class 'set'>

# %%
set1=set("hi i am brijesh")
print(set1)
# Out:
# {'j', 'e', 'h', 'b', 'i', 'm', 'r', ' ', 's', 'a'}

# %%
a=set()
print(type(a))
# Out:
# <class 'set'>

# %%
# set list is list
set1=set(["brijesh","rajesh","kumar"])
# print(type(set1))
print(set1)
# Out:
# {'rajesh', 'brijesh', 'kumar'}

# %%
# set list is tuple
set1=("brijesh","rajesh","kumar")
print(set(set1))
# Out:
# {'rajesh', 'brijesh', 'kumar'}

# %%
set1=("brijesh,rajesh,kumar")
print(set(set1))
# Out:
# {'m', 'u', 'e', 'h', 'b', ',', 'a', 'i', 'k', 'r', 's', 'j'}

# %%
set1=set("brijesh")
print(set1)
# Out:
# {'e', 'h', 'b', 'i', 'r', 's', 'j'}

# %%
# create dictinary to set 
emp={1:"brijesh",2:"rajesh",3:"kumar",4:"kavish"}
print(set(emp))
# Out:
# {1, 2, 3, 4}
