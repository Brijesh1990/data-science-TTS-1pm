# %%
# data frame : it is used to give a tabular layout 
# data is a collection of informations 
# data is two types ...
# 1) structured data   2) unstructred data
# structured data : it is a form form tables and csv and excels 
# unstrucred data : it is a form of .image | text | videos etc 
# data frame take a data in structured formate 
# install a libraries of pandas
import pandas as pd
foodvastage={
            "fodname":["pizza","burger","rotli","manchurian"],
            "wastage":["200gm","1kg","200 peace","5kg"],
            "qty":[200,100,50,20],
    
}

data=pd.DataFrame(foodvastage)
print(data)
# Out:
#       fodname    wastage  qty
# 0       pizza      200gm  200
# 1      burger        1kg  100
# 2       rotli  200 peace   50
# 3  manchurian        5kg   20

# %%
import pandas as pd
foodvastage={
            "fodname":["pizza","burger","rotli","manchurian"],
            "wastage":["200gm","1kg","200 peace","5kg"],
            "qty":[200,100,50,20],
    
}

data=pd.DataFrame(foodvastage,index=[1,2,3,4])
print(data)
# Out:
#       fodname    wastage  qty
# 1       pizza      200gm  200
# 2      burger        1kg  100
# 3       rotli  200 peace   50
# 4  manchurian        5kg   20

# %%
import pandas as dd
foodvastage={
            "fodname":["pizza","burger","rotli","manchurian"],
            "wastage":["200gm","1kg","200 peace","5kg"],
            "qty":[200,100,50,20],
    
}

a=dd.DataFrame(foodvastage,index=[1,2,3,4])
print(data)
# Out:
#       fodname    wastage  qty
# 1       pizza      200gm  200
# 2      burger        1kg  100
# 3       rotli  200 peace   50
# 4  manchurian        5kg   20

# %%
# delete from list
numbers=[10,20,30,40,50]
print(numbers.pop(2))
# Out:
# 30

# %%
# delete from list
numbers=[10,20,30,40,50]
del numbers[2]
print(numbers)
# Out:
# [10, 20, 40, 50]
