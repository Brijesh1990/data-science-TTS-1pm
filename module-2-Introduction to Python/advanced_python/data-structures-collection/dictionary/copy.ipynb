# %%
data1={1:"devanshu",2:"lotus",3:"banana",4:"apple",5:"pineapple"}
data2={6:"keval",7:"labhu"}
data2=data1.copy()
print(data2)
# Out:
# {1: 'devanshu', 2: 'lotus', 3: 'banana', 4: 'apple', 5: 'pineapple'}
