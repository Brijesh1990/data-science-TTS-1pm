# %%
# what is dictionary  ? 
# dictionary is a part of data structures python or collections 
# dictionary is used to stored data {} in form of key:value paired
# dictionary is provides mutables can be changed or update data 
# dictionary is used to stored data and access data in {key:value} with all data types 

emp={1:"brijesh",2:"devanshu",3:"meet"}
print(emp)
print(type(emp))
# Out:
# {1: 'brijesh', 2: 'devanshu', 3: 'meet'}
# <class 'dict'>

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
print(emp[2])
# Out:
# devanshu

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
print(emp[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 2
#       1 emp={1:"brijesh",2:"devanshu",3:"meet"}
# ----> 2 print(emp[0])
#
# KeyError: 0

# %%
emp={"a":"brijesh","b":"devanshu","c":"meet"}
print(emp)
# Out:
# {'a': 'brijesh', 'b': 'devanshu', 'c': 'meet'}

# %%
emp={"a":"brijesh","b":"devanshu","c":"meet"}
print(emp['a'])
# Out:
# brijesh
