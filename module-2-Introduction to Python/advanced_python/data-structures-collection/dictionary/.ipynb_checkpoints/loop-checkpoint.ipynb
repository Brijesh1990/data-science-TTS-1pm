# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for i in emp:
    print(i)
# Out:
# 1
# 2
# 3

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for i in emp.values:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 emp={1:"brijesh",2:"devanshu",3:"meet"}
# ----> 2 for i in emp.value:
#       3     print(i)
#
# AttributeError: 'dict' object has no attribute 'value'
