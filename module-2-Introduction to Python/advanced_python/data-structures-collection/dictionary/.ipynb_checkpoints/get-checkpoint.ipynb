# %%
# get method in dictinary 
# emp={"a":"brijesh","b":"devanshu","c":"meet"}
emp={1:"brijesh",2:"devanshu",3:"meet"}
print(emp.get(1))
# Out:
# brijesh

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
print(emp.get(3))
# Out:
# meet

# %%
emp={"a":"brijesh","b":"devanshu","c":"meet"}
print(emp.get("c"))
# Out:
# meet
