# %%
# how to convert a list into dictionary
key=[1,2,3,4]
value=["brijesh","devanshu","rajesh","kumar"]
# print(dict(key,value))
# res=dict(zip(key,value))
# print(res)

res=dict(unzip(key,value))
print(res)
# Out:
# {1: 'brijesh', 2: 'devanshu', 3: 'rajesh', 4: 'kumar'}
