# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for i in emp:
    print(i)
# Out:
# 1
# 2
# 3

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for i in emp.values():
    print(i)
# Out:
# brijesh
# devanshu
# meet

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for i,j in emp.items():
    print(i,j)
# Out:
# 1 brijesh
# 2 devanshu
# 3 meet

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for key,value in emp.items():
    print(key,value)
# Out:
# 1 brijesh
# 2 devanshu
# 3 meet

# %%
emp={1:"brijesh",2:"devanshu",3:"meet"}
for key in emp.items():
    print(key)
    print(type(key))
# Out:
# (1, 'brijesh')
# <class 'tuple'>
# (2, 'devanshu')
# <class 'tuple'>
# (3, 'meet')
# <class 'tuple'>
