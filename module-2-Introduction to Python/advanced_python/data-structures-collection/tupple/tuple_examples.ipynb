# %%
#what is tuple ? 
# a tuple is a part of collection in python 
# a tuple stored data in ()
# a tuple is immutable 
# a tule can stored all data types 
# a tuple is defined print(tup)

employee=("mitesh","devanshu","kumar")
print(employee)
print(type(employee))
# Out:
# ('mitesh', 'devanshu', 'kumar')
# <class 'tuple'>

# %%
# list to tuple
emp=["mitesh","devanshu","kumar"]
print(emp)
print(type(emp))
# Out:
# ['mitesh', 'devanshu', 'kumar']
# <class 'list'>

# %%
li=(1,2,3,4,5,6)
employee=("mitesh","devanshu","kumar")
salary=(15500,18500,20500)
print(li,"\n",employee,"\n",salary)
# Out:
# (1, 2, 3, 4, 5, 6)
#  ('mitesh', 'devanshu', 'kumar')
#  (15500, 18500, 20500)

# %%
li = ("mitesh",) * 5
for item in li:
    print(item)
# Out:
# mitesh
# mitesh
# mitesh
# mitesh
# mitesh

# %%
# accessing a tupple
employee=("mitesh","devanshu","kumar")
print(employee[1:])
# Out:
# ('devanshu', 'kumar')

# %%
employee=("mitesh","devanshu","kumar")
print(employee[::-1])
# Out:
# ('kumar', 'devanshu', 'mitesh')

# %%
employee=("mitesh","devanshu","kumar")
print(employee[:-1])
# Out:
# ('mitesh', 'devanshu')

# %%
li=("mitesh")
print((li+"\n")*5)
# Out:
# mitesh
# mitesh
# mitesh
# mitesh
# mitesh

# %%
li = ("mitesh",) * 5
for item in li:
    print(item)
# Out:
# mitesh
# mitesh
# mitesh
# mitesh
# mitesh

# %%
li=["devanshu"]
print(tuple(li))
# Out:
# ('devanshu',)
