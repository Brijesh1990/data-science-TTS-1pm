# %%
# what is list ?
# list is a set of orders that can be stored inside of []
# list is provides mutable objects ...can be changed | insert | delete the list items 
# list sometimes called to stored multiple data in a list 
# list is collection of multiple data in a single variables 
# list work as array 
# employee=["devenshu","brijesh","rajesh"]
# print(employee)

employee=["devenshu","brijesh","rajesh"]
print(employee[0])
print(employee[2])
print(employee[1])
# Out:
# devenshu
# rajesh
# brijesh

# %%
number=[1,2,3,4,5,6,45,89,65]
print(number)
# Out:
# [1, 2, 3, 4, 5, 6, 45, 89, 65]

# %%
number=[1,2.5,3.5,4,5,6.5,45.5,89.5,65]
print(number)
# Out:
# [1, 2.5, 3.5, 4, 5, 6.5, 45.5, 89.5, 65]

# %%
number=[2]*5
print(number)

number1=[5]*5
print(number1)
# Out:
# [2, 2, 2, 2, 2]
# [5, 5, 5, 5, 5]

# %%
name=[125,45,"brijesh","devanshu"]
print(name)
# Out:
# [125, 45, 'brijesh', 'devanshu']

# %%
# how can we defined a list inside of  tuple () with another way
employee=list((1,2,3,"brijesh",125.568))
print(employee)
print(type(employee))
# Out:
# [1, 2, 3, 'brijesh', 125.568]
# <class 'list'>

# %%
# accessing a list 
employee=[1,2,3,4,5]
print(employee[0])
print(employee[-1])
print(employee[1:4])
# Out:
# 1
# 5
# [2, 3, 4]

# %%
# append data in list : add at last positions
# data=[]
# print(data)
# # append data in list 
# data.append(10)
# print(data)


a=[10,20,30,40]
a.append(50)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       1 # append data in list : add at last positions
#       2 # data=[]
#       3 # print(data)
#       4 # # append data in list
#       5 # data.append(10)
#       6 # print(data)
#       9 a=[10,20,30,40]
# ---> 10 a.append(50,60,70)
#      11 print(a)
#
# TypeError: list.append() takes exactly one argument (3 given)
