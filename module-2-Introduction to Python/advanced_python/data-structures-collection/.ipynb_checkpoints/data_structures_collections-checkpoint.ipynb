# %%
# data collection or data structures in python 
# data structures in python are worked to collection or stored multiples data 
# data stored using data structured in python are some types 

# string 
# list 
# tuple
# dictionary
# array
# set
