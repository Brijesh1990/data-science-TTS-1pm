# %%
sales=int(input('Enter sales price '))
reg=input('Enter your region of sales')
disscount=int(input('Enter disccount'))
final=(sales*disscount)/100
result=sales-final
print(result)
# Out:
# Enter sales price  20000
# Enter your region of sales rjt
# Enter disccount 20
# 16000.0
