# %%
print("hello devanshu")
print("hello brijesh")
print("hello ayushi")
# Out:
# hello devanshu
# hello brijesh
# hello ayushi

# %%
# print is a function of python to print any character , text or numbers 
print("hello devanshu")
print("hello brijesh")
print("hello ayushi")
# Out:
# hello devanshu
# hello brijesh
# hello ayushi

# %%
print("hello devanshu", end="")
print("hello brijesh")
# Out:
# hello devanshuhello brijesh

# %%
print("hello devanshu", end="")
print("hello brijesh", end="")
print("hello ayushi")
# Out:
# hello devanshuhello brijeshhello ayushi

# %%
# here end ="" is used inside of print() function to print your character | text | numbers in inline row
print("hello devanshu", end="")
print("hello kumar", end="")
print("hello rajiv")
# Out:
# hello devanshuhello kumarhello rajiv

# %%
# what is variables : A variable is stored information about data i.e called variables
# A variable just like container where we stored information about data i.e called variables 
# in python there is no need to defined any identifier to decalred variables 
# A variables defined to follow some rules .. 

    # 1) not need to declred identifire
    #         a=10 
    #         b="brijesh"
    #         name="hello i am brijesh"

    # 2) any variables can start with _underscore but can start with any character 

    #      _name="brijesh" #wrong method
    #      abc="brijesh"

    # 3) any variables can not start with numbers 
           # 3a=25; wrong method


    #4) any variables can not be start with reserved keyword 

           # if=45;       //wrong method
           # for=145.56; //wrong method

    # 5) any variables can not accept whitespace 

    #        a b=15; #wrong method

    # Note : used type() method to know the data type of any variables 

# _a=10;
# print(_a)

# abc=14.56
# name="brijesh kumar pandey"
# if=45;
# print(abc)
# print(name)
# print(if)

# 3a=45;
# print(3a)

# a3=45;
# a4=45
# a5=a3+a4
# print(a5)

# a b=45
# print(a b)

# a=45
# name="hi devanshu"
# d=14.56
# print(a,name,d)

a=14.5
b=14
name='hello devanshu'
abc="hi brijesh"

print(type(a))
print(type(b))
print(type(name))
print(type(abc))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
