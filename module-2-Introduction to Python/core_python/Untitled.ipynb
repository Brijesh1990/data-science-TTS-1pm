# %%
# what is boolean : boolean is a data type of variables 
# boolean values stored 2 types of data true and false

a=True
b=False
print(a)
print(b)
print(type(a))
# Out:
# True
# False
# <class 'bool'>
