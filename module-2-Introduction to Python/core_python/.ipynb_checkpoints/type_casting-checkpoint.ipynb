# %%
""" types casting : type casting is used to convert any data type with another data type of variables 
                     a="17" string to int 
                     1)int
                     2)float
                     3)str

"""
# a=int("17")
# b=20
# c=a+b;
# print(c)


"""a=float("17") 
b=20
c=a+b;
print(c)
print(type(c)) """

# a=str(10);
# print(type(a))

# a=str(10.125);
# print(type(a))

# a=int("10");
# print(type(a))

# a=int('10')
# b=int('20')
# c=a+b
# print(c)


a=10
b=20
c=a+b
print(c)
# Out:
# 30
