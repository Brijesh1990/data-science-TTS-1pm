# %%
#global keyword call function inside of scope or outside of scope
# local function 

def display():
    name="Brijesh" #local
    print(name)
display()
# Out:
# Brijesh

# %%
#global keyword
# x=10
# def ad():
#     x=5
# ad()
# print(x)

x=10
def ad():
    global x
    x=5
ad()
print(x)

#global is keyword to declined by max users
# Out:
# 5
