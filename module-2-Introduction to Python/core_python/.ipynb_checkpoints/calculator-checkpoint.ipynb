# %%
# calculator 
print('select numbers 1 for additions 2 for substractions 3 for multiplications 4 for devisions')
a=int(input('Enter a values '))
b=int(input('Enter b values '))
number=int(input('Enter a Numbers :'))
if number==1:
    c=a+b
    print(c)
elif number==2:
    c=a-b
    print(c)
elif number==3:
    c=a*b
    print(c)
elif number==4:
    if b!=0:
        c=a/b
        print(c)
    else:
        print('sorry not able to divisible by zero try another numbers')
        
       
       
else:
    print('sorry you are enter only 1,2,3,4 for calculations try again')
# Out:
# select numbers 1 for additions 2 for substractions 3 for multiplications 4 for devisions
# Enter a values  10
# Enter b values  2
# Enter a Numbers : 4
# 5.0
