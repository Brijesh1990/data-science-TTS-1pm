# %%
# create a string
# enter age
name=input('Enter your age :')
print(name)
# Out:
# Enter your age : 34
# 34

# %%
name=input('Enter your age :')
ad=input('Enter 2 years more :')
res=name+ad
print('you are',res,'Years old')
# Out:
# Enter your age : 32
# Enter 2 years more : 2
# you are 322 Years old

# %%
# type casting float, int, str
name=int(input('Enter your age :'))
ad=int(input('Enter 2 years more :'))
res=name+ad
print('you are',res,'Years old')
# Out:
# Enter your age : 32
# Enter 2 years more : 2
# you are 34 Years old

# %%
# type casting float, int, str
totalamm=50000
account=int(input('Enter your bank account :'))
pin=int(input('Enter your pincode  :'))
withdrawl=int(input('Enter your withdrawl ammount :'))
res=totalamm-withdrawl
print('you have an remaining ammount of :',res,'in your account')
