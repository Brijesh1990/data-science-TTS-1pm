# %%
# reused a calc 
import calc
result1=calc.add(10,20)
print(result1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # reused a calc
# ----> 2 import calc
#       3 result1=calc.add(10,20)
#       4 print(result1)
#
# ModuleNotFoundError: No module named 'calc'
