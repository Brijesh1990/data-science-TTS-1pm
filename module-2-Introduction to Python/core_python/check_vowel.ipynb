# %%
# check vowel or constonent
char=input('Enter a character').lower()
name=['a','i','e','o','u']
if char in name:
    print('Name is vowel')
else:
    print('Name is consonets')
# Out:
# Enter a character ABCD
# Name is consonets

# %%
# check vowel or constonent
# char=input('Enter a character').lower()
char=input('Enter a character').upper()
# name=['a','i','e','o','u']
# vowels="Aeiou"
vowels=['A','I','E','O','U']
# vowels=['a','i','e','o','u']
if char in vowels:
    print('Name is vowel')
else:
    print('may be eneter uppercase please write a lower case name')
# Out:
# Enter a character a
# Name is vowel
