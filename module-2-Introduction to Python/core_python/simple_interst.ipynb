# %%
# simple interest
# si =p*n*r/100
p=int(input('Enter principle ammount'))
n=int(input('Enter Numbers of Time'))
r=int(input('Enter ROI'))
si=p*n*r/100
print('simple interst of principle ammount :',si)
# Out:
# Enter principle ammount 50000
# Enter Numbers of Time 2
# Enter ROI 10
# simple interst of principle ammount : 10000.0
