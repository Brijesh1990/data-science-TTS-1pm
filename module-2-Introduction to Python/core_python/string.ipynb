# %%
# string is a set of characters i.e used to enclosed within "" or '' i.e called string
a='hi my name is devanshu'
print(a)
# Out:
# hi my name is devanshu

# %%
# name='my name is brijesh
# my age is 35 years
# i have to done mtech
# ny working in corporate'
# print(name)

name='''my name is brijesh
my age is 35 years
i have to done mtech
ny working in corporate'''

print(name)
# Out:
# my name is brijesh
# my age is 35 years
# i have to done mtech
# ny working in corporate

# %%
name="""my name is brijesh
my age is 35 years
i have to done mtech
ny working in corporate"""
print(name)
# Out:
# my name is brijesh
# my age is 35 years
# i have to done mtech
# ny working in corporate

# %%
'''name='my name is brijesh
my age is 35 years
i have to done mtech
ny working in corporate'
print(name)'''
# Out:
# "name='my name is brijesh\nmy age is 35 years\ni have to done mtech\nny working in corporate'\nprint(name)"
