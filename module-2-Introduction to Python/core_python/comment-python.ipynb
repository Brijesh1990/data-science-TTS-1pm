# %%
# what is comment : comment is used to disables output in code 
# types of comment :1) single line comment 2) multiline comment

# single line comment 
# a=20
# b=30
# # d=45;
# c=a+b;
# print(c)


# 2) multiline comment
""" 
multiline comment is used to disables code in multiline of code 
this is basically used to comment multiline 
"""
a=20
print(a)
# Out:
# 20
