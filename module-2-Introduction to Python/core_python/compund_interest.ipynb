# %%
# create a find coumpound interest
p=int(input('Enter a ammount :'))
n=int(input('Enter Number of years :'))
r=int(input('Enter ROI :'))
ci=p*(pow((1+r/100),n))
print(ci)
# Out:
# Enter a ammount : 50000
# Enter Number of years : 2
# Enter ROI : 5
# 55125.0
