# %%
# print a start triangle pattern using loop 
for i in range(1,6):
    print("*" *i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
    print("*" *i)
# Out:
# *
# **
# ***
# ****
# *****
