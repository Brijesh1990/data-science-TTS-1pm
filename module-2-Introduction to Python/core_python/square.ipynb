# %%
# square of numbers take from users 
num=int(input('Enter a Numbers '))
res=pow(num,3)
print(res)
# Out:
# Enter a Numbers  3
# 27

# %%
# create a programme for find a area of circle
# a=pie*r2  
# pie=3.14
